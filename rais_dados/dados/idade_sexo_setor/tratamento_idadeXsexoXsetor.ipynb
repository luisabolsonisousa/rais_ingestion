# %%
import pandas as pd
import numpy as np
import re
from unidecode import unidecode
import os
import datetime
import glob

# %%
def read_file(file):
    """
    read file line by line
    """
    lines = [line.rstrip() for line in open(file, 'r', encoding='ISO-8859-15')]
    return lines

def find_idx(lines, substring):
    """
    find the line indexes containing a substring
    """
    idx = []
    count = 0
    for line in lines:
        if substring in line:
            idx.append(count)
        count += 1
    return idx

def keep_cols_by_name(df, substring):
    df = df.filter(regex=substring)
    return df


def unstack_double_header(df, col_index):
    """
    transform df with double headers into single header
    """

    # Unstack two headers
    cols = df.iloc[col_index][1::].unique()
    cols = (list(set([col.strip() for col in cols])))

    result = pd.DataFrame()
    for col in cols:

        # get the indexes of the desired columns
        idx = np.where(df.iloc[0] == col)[0]
        # insert first column (key)
        idx = np.insert(idx, 0, 0, axis=0)

        # filter just the desired columns and removes lines from headers
        df_aux = df.loc[2::,idx]
        df_aux.columns = df.loc[1, idx]

        df_aux["new_col"] = col
        result = pd.concat([result, df_aux])

    return result

def stack_same_tables_in_same_file(idxs, lines):
    result = pd.DataFrame()
    for i in range(1, len(idxs)):
        fst_idx=idxs[i-1]+2
        last_idx=idxs[i]-1

        df = pd.DataFrame([line.split(";") for line in lines[fst_idx:last_idx]])
        aux = unstack_double_header(df, 0)
        aux["table"] = lines[fst_idx-2]
        result = pd.concat([result, aux])

        print(f"\t Time: {datetime.datetime.now().strftime('%Y%m%d %H:%M:%S')} - Iteraction: {i} - First idx = {fst_idx} - Last idx = {last_idx} - Shape before unstack: {df.shape} - Shape after unstack: {aux.shape} - Shape after append: {result.shape} ")
    return result

def df_janitor(df):

    # Correct new columns added names
    df = df.rename({"new_col":"Faixa Etaria", "table":"Sexo"}, axis='columns')

    # adjust content of the lines of the column Faixa Etaria
    df["Faixa Etaria"] = [re.sub(r'^\s*\d+:', '', re.sub(r'\.\d+\s*$', '', s)) for s in df["Faixa Etaria"]]

    # adjust content of the lines of the column Sexo
    df["Sexo"] = [re.sub("Sexo Trabalhador = ", '', s) for s in df["Sexo"]]
    df["Sexo"] = [re.sub(r'^\s*\d+:', '', re.sub(r'\.\d+\s*$', '', s)) for s in df["Sexo"]]

    # remove unwanted lines
    to_remove = ['{ñ class}', 'Total', '', 'Seleções vigentes', 'Variável', 'Ano', 'Vínculo Ativo 31/12']
    df = df[~df.iloc[:,0].isin(to_remove)]
    df = df[~df["Faixa Etaria"].isin(to_remove)]
    df = df[~df["Sexo"].isin(to_remove)]

    # transform string nan to effective nan
    df = df.replace("NaN", np.nan)

    # adjust columns names
    df.columns = [re.sub(r'^\s*\d+:', '', re.sub(r'\.\d+\s*$', '', coluna)) for coluna in df.columns]

    # adjust line names
    df.iloc[:,0] = df.iloc[:,0].str.split(':').str[1]

    # remove special chars
    df.columns = [re.sub(r'^\s*\d+:', '', re.sub(r'\.\d+\s*$', '', coluna)) for coluna in df.columns]
    df.columns = [re.sub(r'[^a-zA-Z0-9]+', '_', unidecode(coluna.lower())) for coluna in df.columns]

    return df

def load_idadeXsexoXsetor(file):
    lines = read_file(file)
    substring = "Sexo Trabalhador = "
    idxs = find_idx(lines, substring)
    # adding the last line of the file (+1 to be ok with the logic below)
    idxs.append(len(lines)+1)

    # read the file and stack the tables
    result = stack_same_tables_in_same_file(idxs, lines)

    # clean the output
    df = df_janitor(result)

    df["arquivo"] = os.path.split(file)[1]

    return df

# %%
path = os.getcwd()
extension = 'csv'
os.chdir(path)
files_csv = glob.glob('*.{}'.format(extension))

df_final = pd.DataFrame()
for i in files_csv:
    aux = load_idadeXsexoXsetor(i)
    df_final = pd.concat([df_final, aux])
    print(f"Time: {datetime.datetime.now().strftime('%Y%m%d %H:%M:%S')} - File {i}")

df_final.to_csv("load_idadeXsexoXsetor.csv")
# Out:
# 	 Time: 20240128 17:47:49 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 261) - Shape after unstack: (280, 30) - Shape after append: (280, 30)
# 	 Time: 20240128 17:47:49 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 261) - Shape after unstack: (280, 30) - Shape after append: (560, 30)
# 	 Time: 20240128 17:47:49 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 261) - Shape after unstack: (340, 30) - Shape after append: (900, 30)
# Time: 20240128 17:47:49 - File idadeXsexoXsetorX2008.csv
# 	 Time: 20240128 17:47:49 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 248) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:49 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 248) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:49 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 248) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:49 - File idadeXsexoXsetorX2020.csv
# 	 Time: 20240128 17:47:49 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 248) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:49 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 248) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:49 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 248) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:49 - File idadeXsexoXsetorX2021.csv
# 	 Time: 20240128 17:47:49 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 254) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:49 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 254) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:49 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 254) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:49 - File idadeXsexoXsetorX2009.csv
# 	 Time: 20240128 17:47:49 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 249) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:49 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 249) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:49 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 249) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:49 - File idadeXsexoXsetorX2019.csv
# 	 Time: 20240128 17:47:49 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 249) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:49 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 249) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:49 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 249) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:49 - File idadeXsexoXsetorX2018.csv
# 	 Time: 20240128 17:47:49 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 261) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:49 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 261) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:49 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 261) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:49 - File idadeXsexoXsetorX2002.csv
# 	 Time: 20240128 17:47:49 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 249) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:49 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 249) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 249) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:50 - File idadeXsexoXsetorX2016.csv
# 	 Time: 20240128 17:47:50 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 254) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 254) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 254) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:50 - File idadeXsexoXsetorX2017.csv
# 	 Time: 20240128 17:47:50 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 266) - Shape after unstack: (280, 30) - Shape after append: (280, 30)
# 	 Time: 20240128 17:47:50 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 266) - Shape after unstack: (280, 30) - Shape after append: (560, 30)
# 	 Time: 20240128 17:47:50 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 266) - Shape after unstack: (340, 30) - Shape after append: (900, 30)
# Time: 20240128 17:47:50 - File idadeXsexoXsetorX2003.csv
# 	 Time: 20240128 17:47:50 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 252) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 252) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 252) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:50 - File idadeXsexoXsetorX2015.csv
# 	 Time: 20240128 17:47:50 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 252) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 252) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 252) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:50 - File idadeXsexoXsetorX2014.csv
# 	 Time: 20240128 17:47:50 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 256) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 256) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 256) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:50 - File idadeXsexoXsetorX2010.csv
# 	 Time: 20240128 17:47:50 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 259) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 259) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 259) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:50 - File idadeXsexoXsetorX2004.csv
# 	 Time: 20240128 17:47:50 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 258) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 258) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 258) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:50 - File idadeXsexoXsetorX2005.csv
# 	 Time: 20240128 17:47:50 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 258) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 258) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 258) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:50 - File idadeXsexoXsetorX2011.csv
# 	 Time: 20240128 17:47:50 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 258) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 258) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 258) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:50 - File idadeXsexoXsetorX2007.csv
# 	 Time: 20240128 17:47:50 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 252) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 252) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 252) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:50 - File idadeXsexoXsetorX2013.csv
# 	 Time: 20240128 17:47:50 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 257) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 257) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 257) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:50 - File idadeXsexoXsetorX2012.csv
# 	 Time: 20240128 17:47:50 - Iteraction: 1 - First idx = 2 - Last idx = 32 - Shape before unstack: (30, 258) - Shape after unstack: (280, 29) - Shape after append: (280, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 2 - First idx = 35 - Last idx = 65 - Shape before unstack: (30, 258) - Shape after unstack: (280, 29) - Shape after append: (560, 29)
# 	 Time: 20240128 17:47:50 - Iteraction: 3 - First idx = 68 - Last idx = 104 - Shape before unstack: (36, 258) - Shape after unstack: (340, 29) - Shape after append: (900, 29)
# Time: 20240128 17:47:50 - File idadeXsexoXsetorX2006.csv

# %%
df_final
# Out:
#                       extrativa_mineral prod_mineral_nao_metalico  \
# 2    Porto Velho - RO                 9                       136
# 3     Rio Branco - AC                25                       109
# 4         Manaus - AM                 9                       208
# 5      Boa Vista - RR                 5                        58
# 6          Belém - PA                 2                        61
# ..                ...               ...                       ...
# 24  Porto Alegre - RS                 0                         0
# 25  Campo Grande - MS                 0                         0
# 26        Cuiabá - MT                 0                         0
# 27       Goiânia - GO                 0                         0
# 28      Brasília - DF                 0                         0
#
#    industria_metalurgica industria_mecanica eletrico_e_comunic  \
# 2                     94                 16                  0
# 3                     39                  6                 16
# 4                  1.483              1.569              3.629
# 5                      5                  5                  1
# 6                    126                 22                 19
# ..                   ...                ...                ...
# 24                     3                  2                  3
# 25                     0                  0                  0
# 26                     0                  0                  0
# 27                     3                  0                  0
# 28                     1                  0                  0
#
#    material_de_transporte madeira_e_mobiliario papel_e_graf  \
# 2                      14                  125           45
# 3                       9                  228           26
# 4                   4.419                  184          655
# 5                       0                   22           26
# 6                      90                  326          226
# ..                    ...                  ...          ...
# 24                      2                    2           11
# 25                      0                    0            0
# 26                      1                    0            0
# 27                      0                    1            0
# 28                      0                    1            5
#
#    borracha_fumo_couros  ... aloj_comunic medicos_odontologicos_vet ensino  \
# 2                    21  ...          669                       128    204
# 3                    31  ...          508                        38    104
# 4                   869  ...        3.071                       272    552
# 5                     6  ...          380                        36    126
# 6                    79  ...        3.125                       450    484
# ..                  ...  ...          ...                       ...    ...
# 24                    3  ...          259                       168    835
# 25                    1  ...           33                        20     12
# 26                    0  ...           14                         4     15
# 27                    0  ...           64                        98     21
# 28                    0  ...          159                        42     76
#
#    administracao_publica agricultura _n_class_   total faixa_etaria  \
# 2                  2.329         140         0  11.024      18 A 24
# 3                  1.056         229         0   7.019      18 A 24
# 4                  2.769         294         0  45.142      18 A 24
# 5                    707          89         0   4.327      18 A 24
# 6                  4.637         242         0  25.679      18 A 24
# ..                   ...         ...       ...     ...          ...
# 24                   342           4       NaN   2.081   65 OU MAIS
# 25                   172           3       NaN     269   65 OU MAIS
# 26                   237           1       NaN     299   65 OU MAIS
# 27                   486           1       NaN     738   65 OU MAIS
# 28                 1.244           3       NaN   1.749   65 OU MAIS
#
#          sexo                    arquivo
# 2   Masculino  idadeXsexoXsetorX2008.csv
# 3   Masculino  idadeXsexoXsetorX2008.csv
# 4   Masculino  idadeXsexoXsetorX2008.csv
# 5   Masculino  idadeXsexoXsetorX2008.csv
# 6   Masculino  idadeXsexoXsetorX2008.csv
# ..        ...                        ...
# 24   Feminino  idadeXsexoXsetorX2006.csv
# 25   Feminino  idadeXsexoXsetorX2006.csv
# 26   Feminino  idadeXsexoXsetorX2006.csv
# 27   Feminino  idadeXsexoXsetorX2006.csv
# 28   Feminino  idadeXsexoXsetorX2006.csv
#
# [8640 rows x 31 columns]
