# %%
import pandas as pd
import numpy as np
import re
from unidecode import unidecode
import os
import glob

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_columns', None)

# %%
def primeiros_tratamentos(df):
    ###########primeiros tratamentos
    indice_selecoes = df[df['Capital'] == "{ñ class}"].index[0]
    # Apagar as linhas a partir desse índice até o final
    df = df.iloc[:indice_selecoes]
    #tratando top row que esta deslocada
    #df.iloc[0, 1:] = df.iloc[0, :-1].values
    #deletando registros que nao tem informações
    df = df[df[' Faixa Remun Média (SM)'] != '{ñ class}']
    #valores NaN em nulo 
    df = df.replace("NaN", np.nan)
    #preenchendo linhas nan para localidade
    df['Capital'] = df['Capital'].ffill()
    #deletando oq vem antes do nome da capital
    df['Capital'] = df['Capital'].str.split(':').str[1]
    #deletar linhas de totais
    df = df[df[' Faixa Remun Média (SM)'] != 'Total']
    #apagar todas as colunas com total e ignorado no nome
    df = df.drop(df.filter(like='Total').columns, axis=1)
    df = df.drop(df.filter(like='Ignorado').columns, axis=1)
    #df.columns =  [re.sub(r"^\d+:", "", re.sub(r"\.\d+$", "", coluna)) for coluna in df.columns]
    df.columns = [re.sub(r'^\s*\d+:', '', re.sub(r'\.\d+\s*$', '', coluna)) for coluna in df.columns]
    return df

# %%
#separando masculino
def criando_df_masculino(df,ano):
    masculino_cols = ['Capital', ' Faixa Remun Média (SM)','Masculino'] 
    df_m=df[masculino_cols]
    new_header = ["capital","faixa_remuneracao_media_sm","total_pessoas"]

    df_m = df_m[0:]

    df_m.columns = new_header 
    #apagando as colunas duplicadas pq misteriosamente elas duplicam muitas vezes 
    df_m = df_m.loc[:, ~df_m.columns.duplicated()]
    df_m["sexo"] = "M"
    df_m["ano"] = ano
    df_m.columns =[re.sub(r"^\d+:", "", coluna) for coluna in df_m.columns]
    df_m = df_m.drop(df_m.filter(like='Total').columns, axis=1)
    df_m = df_m.drop(df_m.filter(like='{ñ class}').columns, axis=1)
    return df_m

# %%
#separando feminino
def criando_df_feminino(df,ano):
    feminino_cols = ['Capital', ' Faixa Remun Média (SM)',"Feminino"] 
    df_f=df[feminino_cols]
    
  
    new_header = ["capital","faixa_remuneracao_media_sm","total_pessoas"]

    df_f = df_f[0:]

    df_f.columns = new_header 
    #apagando as colunas duplicadas pq misteriosamente elas duplicam muitas vezes 
    df_f = df_f.loc[:, ~df_f.columns.duplicated()]
    df_f["sexo"] = "F"
    df_f["ano"] = ano
    df_f.columns =[re.sub(r"^\d+:", "", coluna) for coluna in df_f.columns]
    df_f = df_f.drop(df_f.filter(like='Total').columns, axis=1)
    df_f = df_f.drop(df_f.filter(like='{ñ class}').columns, axis=1)
    
    return df_f

# %%
for root, dirs, files in os.walk("/Users/bolsolui/Documents/personal/MECAI/git/rais_dados/new_data/total_pessoas"):
    final_file_name=""
    df_final= pd.DataFrame()
    print(f"root:{root}")
    path = root
    extension = 'csv'
    os.chdir(path)
    files_csv = glob.glob('*.{}'.format(extension))
    
    if files_csv:
        
        for i in files_csv:
            print(i)
            resultado = re.search(r'^[^0-9]+', i).group()

            # Remove o último caractere se for um sublinhado
            final_file_name = resultado.rstrip('_')
            
            #print(f"root:{root} e lista: {files_csv} e file : {final_file_name}")
            df = pd.read_csv(i,sep=";",  encoding='latin-1',skiprows=1, header=[0])
            ano = re.search(r'\d{4}', i).group()
            df = primeiros_tratamentos(df)
            df_f = criando_df_feminino(df,ano)
            df_m = criando_df_masculino(df,ano)
            df_final = pd.concat([df_final,df_f, df_m])
            print(f"File {i}, com shape {df.shape} do ano {ano}, df feminino: {df_f.shape}, df masculino: {df_m.shape} e df final: {df_final.shape}")


        df_final = df_final.drop(df_final.filter(like='{ñ class}').columns, axis=1)
        # Remover acentuação
        df_final['faixa_remuneracao_media_sm'] = df_final['faixa_remuneracao_media_sm'].apply(lambda x: unidecode(str(x)))
        df_final['capital'] = df_final['capital'].apply(lambda x: unidecode(str(x)))
        #tirar espaco 
        df_final['faixa_remuneracao_media_sm'] = df_final['faixa_remuneracao_media_sm'].str.replace(' ', '_')
        df_final['capital'] = df_final['capital'].str.replace('-', '_').str.replace(' ', '_')
        # Transformar em minúsculas
        df_final['faixa_remuneracao_media_sm'] = df_final['faixa_remuneracao_media_sm'].str.lower()
        df_final['capital'] = df_final['capital'].str.lower()
        print(f"ESCREVENDO DF FINAL:   {final_file_name}")
        df_final.to_csv(f'{final_file_name}.csv', index=False)
        print(f"Finalizado:   {final_file_name}")
# Out:
# root:/Users/bolsolui/Documents/personal/MECAI/git/rais_dados/new_data/total_pessoas
# total_pessoas_2020.csv
# File total_pessoas_2020.csv, com shape (324, 4) do ano 2020, df feminino: (324, 5), df masculino: (324, 5) e df final: (648, 5)
# total_pessoas_2008.csv
# File total_pessoas_2008.csv, com shape (324, 4) do ano 2008, df feminino: (324, 5), df masculino: (324, 5) e df final: (1296, 5)
# total_pessoas_2009.csv
# File total_pessoas_2009.csv, com shape (324, 4) do ano 2009, df feminino: (324, 5), df masculino: (324, 5) e df final: (1944, 5)
# total_pessoas_2021.csv
# File total_pessoas_2021.csv, com shape (324, 4) do ano 2021, df feminino: (324, 5), df masculino: (324, 5) e df final: (2592, 5)
# total_pessoas_2022.csv
# File total_pessoas_2022.csv, com shape (324, 4) do ano 2022, df feminino: (324, 5), df masculino: (324, 5) e df final: (3240, 5)
# total_pessoas_2019.csv
# File total_pessoas_2019.csv, com shape (324, 4) do ano 2019, df feminino: (324, 5), df masculino: (324, 5) e df final: (3888, 5)
# total_pessoas_2018.csv
# File total_pessoas_2018.csv, com shape (324, 4) do ano 2018, df feminino: (324, 5), df masculino: (324, 5) e df final: (4536, 5)
# total_pessoas_2015.csv
# File total_pessoas_2015.csv, com shape (324, 4) do ano 2015, df feminino: (324, 5), df masculino: (324, 5) e df final: (5184, 5)
# total_pessoas_2014.csv
# File total_pessoas_2014.csv, com shape (324, 4) do ano 2014, df feminino: (324, 5), df masculino: (324, 5) e df final: (5832, 5)
# total_pessoas_2016.csv
# File total_pessoas_2016.csv, com shape (324, 4) do ano 2016, df feminino: (324, 5), df masculino: (324, 5) e df final: (6480, 5)
# total_pessoas_2017.csv
# File total_pessoas_2017.csv, com shape (324, 4) do ano 2017, df feminino: (324, 5), df masculino: (324, 5) e df final: (7128, 5)
# total_pessoas_2013.csv
# File total_pessoas_2013.csv, com shape (324, 4) do ano 2013, df feminino: (324, 5), df masculino: (324, 5) e df final: (7776, 5)
# total_pessoas_2007.csv
# File total_pessoas_2007.csv, com shape (324, 4) do ano 2007, df feminino: (324, 5), df masculino: (324, 5) e df final: (8424, 5)
# total_pessoas_2006.csv
# File total_pessoas_2006.csv, com shape (324, 4) do ano 2006, df feminino: (324, 5), df masculino: (324, 5) e df final: (9072, 5)
# total_pessoas_2012.csv
# File total_pessoas_2012.csv, com shape (324, 4) do ano 2012, df feminino: (324, 5), df masculino: (324, 5) e df final: (9720, 5)
# total_pessoas_2010.csv
# File total_pessoas_2010.csv, com shape (324, 4) do ano 2010, df feminino: (324, 5), df masculino: (324, 5) e df final: (10368, 5)
# total_pessoas_2011.csv
# File total_pessoas_2011.csv, com shape (324, 4) do ano 2011, df feminino: (324, 5), df masculino: (324, 5) e df final: (11016, 5)
# ESCREVENDO DF FINAL:   total_pessoas
# Finalizado:   total_pessoas
